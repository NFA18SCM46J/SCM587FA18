# %% [markdown]
# # Plot the Graph for the total number of issues with different labels created and closed on every date on GitHub for SPM587FA18 issues project

# %% [markdown]
# ### Example of Issue Form Filled out

# %% [raw]
# Author: PSCM587FA18
# created_at: 2018-11-06,
# labels: bug,
# State: closed,
# issue_number: 1,
# closed_at: 2018-11-06

# %% [markdown]
# ### Data Set File:  SPM587FA18issues.json

# %%
import os 
import pandas as pd                                    # panda's nickname is pd 
import numpy as np                                     # numpy as np 
from pandas import DataFrame, Series                   # for convenience 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# # Requirement : Get the total number of issues with different labels for every date and plot them in a stacked chart

# %%
# Read the JSON file into a list of dictionaries 

import json 
list_of_issues_dict_data = [json.loads(line) for line in open('SPM587FA18issues.json')]

# %%
# Create the DataFrame object for the list_of_issues_dict_data object 

issues_df = DataFrame(list_of_issues_dict_data)

# %%
# Sanity test: print first 10 rows in our DataFrame 

issues_df.head(10)
# Out:
#         Author   State   closed_at  created_at  issue_number  \
# 0  AFA18SCM21V  closed  2018-11-17  2018-11-17           354
# 1  SFA18SCM75J  closed  2018-11-17  2018-11-17           352
# 2  AFA18SCM64A  closed  2018-11-17  2018-11-16           350
# 3  BFA18SCM78Z  closed  2018-11-17  2018-11-16           348
# 4  KFA18SCM64T  closed  2018-11-16  2018-11-16           347
# 5  CFA18SCM71R  closed  2018-11-16  2018-11-16           345
# 6  AFA18SCM57S  closed  2018-11-17  2018-11-16           343
# 7       fazfar  closed  2018-11-16  2018-11-16           340
# 8  PFA18SCM42I  closed  2018-11-16  2018-11-16           336
# 9  PFA18SCM15B  closed  2018-11-16  2018-11-16           335
#
#                                               labels
# 0  [Category:Bug, DetectionPhase:Testing, Origina...
# 1  [Category:Bug, DetectionPhase:Testing, Origina...
# 2  [Category:Inquiry, DetectionPhase:Field, Origi...
# 3  [Category:Inquiry, DetectionPhase:Field, Origi...
# 4  [Category:Inquiry, DetectionPhase:Field, Origi...
# 5  [Category:Enhancement, DetectionPhase:Testing,...
# 6  [Category:Bug, DetectionPhase:Testing, Origina...
# 7  [Category:Inquiry, DetectionPhase:Field, Origi...
# 8  [Category:Inquiry, DetectionPhase:Field, Origi...
# 9  [Category:Bug, DetectionPhase:Testing, Origina...

# %%
# Prepare and Clean the dataframe object 

wrangled_issues_df = issues_df[['Author','State','closed_at','created_at','issue_number','labels']] 
wrangled_issues_df.loc[0:len(wrangled_issues_df), 'OriginationPhase']= np.NaN 
wrangled_issues_df.loc[0:len(wrangled_issues_df),'DetectionPhase']= np.NaN 
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Category']= np.NaN 
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Priority']= np.NaN 
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Status']= np.NaN

# %%
wrangled_issues_df.head(10)
# Out:
#         Author   State   closed_at  created_at  issue_number  \
# 0  AFA18SCM21V  closed  2018-11-17  2018-11-17           354
# 1  SFA18SCM75J  closed  2018-11-17  2018-11-17           352
# 2  AFA18SCM64A  closed  2018-11-17  2018-11-16           350
# 3  BFA18SCM78Z  closed  2018-11-17  2018-11-16           348
# 4  KFA18SCM64T  closed  2018-11-16  2018-11-16           347
# 5  CFA18SCM71R  closed  2018-11-16  2018-11-16           345
# 6  AFA18SCM57S  closed  2018-11-17  2018-11-16           343
# 7       fazfar  closed  2018-11-16  2018-11-16           340
# 8  PFA18SCM42I  closed  2018-11-16  2018-11-16           336
# 9  PFA18SCM15B  closed  2018-11-16  2018-11-16           335
#
#                                               labels  OriginationPhase  \
# 0  [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 1  [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 2  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 3  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 4  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 5  [Category:Enhancement, DetectionPhase:Testing,...               NaN
# 6  [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 7  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 8  [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 9  [Category:Bug, DetectionPhase:Testing, Origina...               NaN
#
#    DetectionPhase  Category  Priority  Status
# 0             NaN       NaN       NaN     NaN
# 1             NaN       NaN       NaN     NaN
# 2             NaN       NaN       NaN     NaN
# 3             NaN       NaN       NaN     NaN
# 4             NaN       NaN       NaN     NaN
# 5             NaN       NaN       NaN     NaN
# 6             NaN       NaN       NaN     NaN
# 7             NaN       NaN       NaN     NaN
# 8             NaN       NaN       NaN     NaN
# 9             NaN       NaN       NaN     NaN

# %%
for i in range(0, len(wrangled_issues_df)): 
   if wrangled_issues_df.iloc[i]['labels']: 
        for label in wrangled_issues_df.iloc[i]['labels']: 
            label_name= (label.split(':'))[0] 
            label_value= (label.split(':'))[1] 
            wrangled_issues_df.loc[i, label_name]=label_value

# %%
wrangled_issues_df.head(10)
# Out:
#         Author   State   closed_at  created_at  issue_number  \
# 0  AFA18SCM21V  closed  2018-11-17  2018-11-17           354
# 1  SFA18SCM75J  closed  2018-11-17  2018-11-17           352
# 2  AFA18SCM64A  closed  2018-11-17  2018-11-16           350
# 3  BFA18SCM78Z  closed  2018-11-17  2018-11-16           348
# 4  KFA18SCM64T  closed  2018-11-16  2018-11-16           347
# 5  CFA18SCM71R  closed  2018-11-16  2018-11-16           345
# 6  AFA18SCM57S  closed  2018-11-17  2018-11-16           343
# 7       fazfar  closed  2018-11-16  2018-11-16           340
# 8  PFA18SCM42I  closed  2018-11-16  2018-11-16           336
# 9  PFA18SCM15B  closed  2018-11-16  2018-11-16           335
#
#                                               labels OriginationPhase  \
# 0  [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
# 1  [Category:Bug, DetectionPhase:Testing, Origina...           Design
# 2  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 3  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 4  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 5  [Category:Enhancement, DetectionPhase:Testing,...           Design
# 6  [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
# 7  [Category:Inquiry, DetectionPhase:Field, Origi...           Design
# 8  [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 9  [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
#
#   DetectionPhase     Category  Priority    ...     StatusPallavi Latitute  \
# 0        Testing          Bug       NaN    ...               NaN      NaN
# 1        Testing          Bug  Critical    ...               NaN      NaN
# 2          Field      Inquiry      High    ...               NaN      NaN
# 3          Field      Inquiry      High    ...               NaN      NaN
# 4          Field      Inquiry      High    ...               NaN      NaN
# 5        Testing  Enhancement  Critical    ...               NaN      NaN
# 6        Testing          Bug  Critical    ...               NaN      NaN
# 7          Field      Inquiry       Low    ...               NaN      NaN
# 8          Field      Inquiry    Medium    ...               NaN      NaN
# 9        Testing          Bug  Critical    ...               NaN      NaN
#
#   Longitute DetectionPhasePallavi CategoryPallavi OriginationPhasePallavi  \
# 0       NaN                   NaN             NaN                     NaN
# 1       NaN                   NaN             NaN                     NaN
# 2       NaN                   NaN             NaN                     NaN
# 3       NaN                   NaN             NaN                     NaN
# 4       NaN                   NaN             NaN                     NaN
# 5       NaN                   NaN             NaN                     NaN
# 6       NaN                   NaN             NaN                     NaN
# 7       NaN                   NaN             NaN                     NaN
# 8       NaN                   NaN             NaN                     NaN
# 9       NaN                   NaN             NaN                     NaN
#
#   longitude Address  Latitude  Longitude
# 0       NaN      NaN       NaN        NaN
# 1       NaN      NaN       NaN        NaN
# 2       NaN      NaN       NaN        NaN
# 3       NaN      NaN       NaN        NaN
# 4       NaN      NaN       NaN        NaN
# 5       NaN      NaN       NaN        NaN
# 6       NaN      NaN       NaN        NaN
# 7       NaN      NaN       NaN        NaN
# 8       NaN      NaN       NaN        NaN
# 9       NaN      NaN       NaN        NaN
#
# [10 rows x 33 columns]

# %%
# Plot in Bar Chart the total number of issues created every day for every Detaction Phase 

LabelsReviewedByDate = wrangled_issues_df.groupby(['created_at','DetectionPhase']).created_at.count() 

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False, figsize=(9,9))

# %%
# Plot in Bar Chart the total number of issues created for every Phase based on thier priorites 

LabelsReviewedByDate = wrangled_issues_df.groupby(['Priority','DetectionPhase']).created_at.count() 

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False, figsize=(9,9))

# %%
# Plot in Bar Chart the total number of issues closed every day for every Category 

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','Category']).closed_at.count() 

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red'], grid=False, figsize=(9,9))
